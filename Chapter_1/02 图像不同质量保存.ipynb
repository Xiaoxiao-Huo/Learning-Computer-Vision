# %%
import cv2
img = cv2.imread("1.jpg",1)
cv2.imwrite('test.jpg',img,[cv2.IMWRITE_JPEG_QUALITY,50])
# Out:
# True

# %%
import cv2
img = cv2.imread("1.jpg",1)
cv2.imwrite('test.png',img,[cv2.IMWRITE_PNG_COMPRESSION,0])
# Out:
# True
