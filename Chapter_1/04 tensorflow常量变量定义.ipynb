# %%
import tensorflow as tf
data1 = tf.constant(2,dtype=tf.int32) #定义常量
data2 = tf.Variable(10,name='var') #定义变量，值，名字
print(data1)
print(data2)
'''
sess = tf.Session()
print(sess.run(data1))
init = tf.global_variables_initializer()
sess.run(init)
print(sess.run(data2))
sess.close()
'''
init = tf.global_variables_initializer()
sess = tf.Session()
with sess:
    sess.run(init)
    print(sess.run(data2))
# Out:
# Tensor("Const_2:0", shape=(), dtype=int32)
# <tf.Variable 'var_2:0' shape=() dtype=int32_ref>
# 10
